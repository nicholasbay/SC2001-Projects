# %%
def knapsack(C, n, weights, profits):
#     Computes the maximum profit that can be made by packing objects into a knapsack of capacity C, given n types of objects with weights wi and profits pi.

#     Args:
#         C: The capacity of the knapsack.
#         weights: A list of the weights of the objects.
#         profits: A list of the profits of the objects.

#     Returns:
#         The maximum profit that can be made.

    table=[]
    
    for i in range(C+1):
        table.append(0)
        
    for i in range(0, C+1):
        print("\n\nAt level [", i, "]:")
        for j in range(0, n):
            if weights[j] <= i:
                table[i] = max(table[i] , table[i - weights[j]] + profits[j])
                print("After considering item[", j, "], weight: ", table[i])
    return table[C]

# %%
knapSackCap = 14

n = 3

# array 1
weightsOne = [4, 6, 8]
profitsOne = [7, 6, 9]

# array 2
weightsTwo = [5, 6, 8]
profitsTwo = [7, 6, 9]

choice = input("Which array to use (1 or 2): ")
if choice == '1':
    print("The maximum possible profit is", knapsack(knapSackCap, n, weightsOne, profitsOne))
else:
    print("The maximum possible profit is", knapsack(knapSackCap, n, weightsTwo, profitsTwo))
# Out:
# Which array to use (1 or 2):2
#
#
# At level [ 0 ]:
#
#
# At level [ 1 ]:
#
#
# At level [ 2 ]:
#
#
# At level [ 3 ]:
#
#
# At level [ 4 ]:
#
#
# At level [ 5 ]:
# After considering item[ 0 ], weight:  7
#
#
# At level [ 6 ]:
# After considering item[ 0 ], weight:  7
# After considering item[ 1 ], weight:  7
#
#
# At level [ 7 ]:
# After considering item[ 0 ], weight:  7
# After considering item[ 1 ], weight:  7
#
#
# At level [ 8 ]:
# After considering item[ 0 ], weight:  7
# After considering item[ 1 ], weight:  7
# After considering item[ 2 ], weight:  9
#
#
# At level [ 9 ]:
# After considering item[ 0 ], weight:  7
# After considering item[ 1 ], weight:  7
# After considering item[ 2 ], weight:  9
#
#
# At level [ 10 ]:
# After considering item[ 0 ], weight:  14
# After considering item[ 1 ], weight:  14
# After considering item[ 2 ], weight:  14
#
#
# At level [ 11 ]:
# After considering item[ 0 ], weight:  14
# After considering item[ 1 ], weight:  14
# ...
